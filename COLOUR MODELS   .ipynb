# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
iron =cv2.imread('download.jpg')
print(iron)
# Out:
# [[[71 41 54]
#   [71 40 55]
#   [71 40 55]
#   ...
#   [68 40 29]
#   [68 40 29]
#   [68 40 29]]
#
#  [[71 40 55]
#   [72 41 56]
#   [72 40 57]
#   ...
#   [68 40 29]
#   [68 40 29]
#   [68 40 29]]
#
#  [[73 41 60]
#   [73 41 60]
#   [73 41 60]
#   ...
#   [69 40 31]
#   [69 40 31]
#   [69 40 31]]
#
#  ...
#
#  [[54 34 16]
#   [54 34 16]
#   [54 34 16]
#   ...
#   [55 35 17]
#   [55 35 17]
#   [55 35 17]]
#
#  [[54 34 16]
#   [54 34 16]
#   [54 34 16]
#   ...
#   [55 35 17]
#   [55 35 17]
#   [55 35 17]]
#
#  [[54 34 16]
#   [54 34 16]
#   [54 34 16]
#   ...
#   [55 35 17]
#   [55 35 17]
#   [55 35 17]]]

# %%
plt.imshow(iron)

# %%
b,g,r=cv2.split(iron)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = iron

blue_channel, green_channel, red_channel = cv2.split(img)


red_only = cv2.merge([np.zeros_like(red_channel), np.zeros_like(green_channel), red_channel])
green_only = cv2.merge([np.zeros_like(red_channel), green_channel, np.zeros_like(blue_channel)])
blue_only = cv2.merge([blue_channel, np.zeros_like(green_channel), np.zeros_like(red_channel)])


plt.figure(figsize=(12, 4))

plt.subplot(131)
plt.imshow(cv2.cvtColor(red_only, cv2.COLOR_BGR2RGB))  
plt.title('Red Channel')
plt.axis('off')

plt.subplot(132)
plt.imshow(cv2.cvtColor(green_only, cv2.COLOR_BGR2RGB))  
plt.title('Green Channel')
plt.axis('off')

plt.subplot(133)
plt.imshow(cv2.cvtColor(blue_only, cv2.COLOR_BGR2RGB)) 
plt.title('Blue Channel')
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image
img = iron# Replace with your image file path

# Split the image into RGB channels
blue_channel, green_channel, red_channel = cv2.split(img)

# Compute the CMY channels (complementary of RGB)
cyan_channel = 255 - red_channel
magenta_channel = 255 - green_channel
yellow_channel = 255 - blue_channel

# Merge the channels to create images that only display one color at a time
cyan_only = cv2.merge([cyan_channel, np.zeros_like(green_channel), np.zeros_like(blue_channel)])
magenta_only = cv2.merge([np.zeros_like(red_channel), magenta_channel, np.zeros_like(blue_channel)])
yellow_only = cv2.merge([np.zeros_like(red_channel), np.zeros_like(green_channel), yellow_channel])



# Plot the images
plt.figure(figsize=(12, 4))

plt.subplot(131)
plt.imshow(cv2.cvtColor(cyan_only, cv2.COLOR_BGR2RGB))  # Convert to RGB for proper display
plt.title('Cyan Channel')
plt.axis('off')

plt.subplot(132)
plt.imshow(cv2.cvtColor(magenta_only, cv2.COLOR_BGR2RGB))  
plt.title('Magenta Channel')
plt.axis('off')

plt.subplot(133)
plt.imshow(cv2.cvtColor(yellow_only, cv2.COLOR_BGR2RGB))  
plt.title('Yellow Channel')
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
def rgb_to_cmy(r, g, b): 
   
    c = 1 - r / 255
    m = 1 - g / 255
    y = 1 - b / 255
    return (c, m, y) 
  
c,m,y=rgb_to_cmy(r,g,b)
print([c,m,y])
# Out:
# [array([[0.78823529, 0.78431373, 0.78431373, ..., 0.88627451, 0.88627451,
#         0.88627451],
#        [0.78431373, 0.78039216, 0.77647059, ..., 0.88627451, 0.88627451,
#         0.88627451],
#        [0.76470588, 0.76470588, 0.76470588, ..., 0.87843137, 0.87843137,
#         0.87843137],
#        ...,
#        [0.9372549 , 0.9372549 , 0.9372549 , ..., 0.93333333, 0.93333333,
#         0.93333333],
#        [0.9372549 , 0.9372549 , 0.9372549 , ..., 0.93333333, 0.93333333,
#         0.93333333],
#        [0.9372549 , 0.9372549 , 0.9372549 , ..., 0.93333333, 0.93333333,
#         0.93333333]]), array([[0.83921569, 0.84313725, 0.84313725, ..., 0.84313725, 0.84313725,
#         0.84313725],
#        [0.84313725, 0.83921569, 0.84313725, ..., 0.84313725, 0.84313725,
#         0.84313725],
#        [0.83921569, 0.83921569, 0.83921569, ..., 0.84313725, 0.84313725,
#         0.84313725],
#        ...,
#        [0.86666667, 0.86666667, 0.86666667, ..., 0.8627451 , 0.8627451 ,
# ...

# %%
plt.imshow(iron)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = iron

gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

hsv_img = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

lab_img = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)

rgb_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

cmyk_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
cmyk_img = 255 - cmyk_img  



plt.figure(figsize=(10, 8))

plt.subplot(231)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title('Original Image')
plt.axis('off')

plt.subplot(232)
plt.imshow(gray_img, cmap='gray')
plt.title('Grayscale Image')
plt.axis('off')

plt.subplot(233)
plt.imshow(cv2.cvtColor(hsv_img, cv2.COLOR_BGR2RGB))  
plt.title('HSV Image')
plt.axis('off')


plt.subplot(234)
plt.imshow(cv2.cvtColor(lab_img, cv2.COLOR_BGR2RGB)) 
plt.title('LAB Image')
plt.axis('off')

plt.subplot(235)
plt.imshow(cmyk_img)
plt.title('CMYK Image (Approx)')
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
# Load an image
image = iron

# Convert RGB to HSV
hsv_image = cv2.cvtColor(image, cv2.COLOR_RGB2HSV)

# Alter HSV values (for example: increase saturation and value)
h, s, v = cv2.split(hsv_image)
s = cv2.add(s, 50)  # Increase saturation
v = cv2.add(v, 50)  # Increase value (brightness)

# Merge modified HSV channels
modified_hsv_image = cv2.merge([h, s, v])

# Convert back to RGB
modified_rgb_image = cv2.cvtColor(modified_hsv_image, cv2.COLOR_HSV2RGB)

# Plot original and modified images
plt.figure(figsize=(10, 5))

# Original Image
plt.subplot(1, 2, 1)
plt.imshow(image)
plt.title('Original Image')
plt.axis('off')

# Modified Image
plt.subplot(1, 2, 2)
plt.imshow(modified_rgb_image)
plt.title('Modified Image (HSV Altered)')
plt.axis('off')

plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

iron = iron

# Convert the image from BGR to HSV
hsv_img = cv2.cvtColor(iron, cv2.COLOR_BGR2HSV)

# Split the HSV image into its individual channels
H, S, V = cv2.split(hsv_img)

# Save the individual channels (optional)
cv2.imwrite('H_channel.jpg', H)
cv2.imwrite('S_channel.jpg', S)
cv2.imwrite('V_channel.jpg', V)

# Display the channels
plt.figure(figsize=(12, 4))

# Hue channel
plt.subplot(131)
plt.imshow(H, cmap='hsv')
plt.title('Hue Channel')
plt.axis('off')

# Saturation channel
plt.subplot(132)
plt.imshow(S, cmap='gray')
plt.title('Saturation Channel')
plt.axis('off')

# Value channel
plt.subplot(133)
plt.imshow(V, cmap='gray')
plt.title('Value Channel')
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# Function to convert RGB to CMY
def rgb_to_cmy(r, g, b):
    c = 1 - r / 255.0  # Convert to [0, 1] range
    m = 1 - g / 255.0
    y = 1 - b / 255.0
    return (c, m, y)

# Load the image (replace with your actual image)
img = iron # Replace with the correct image path
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert to RGB for correct color interpretation

# Create an empty array to store the CMY image
cmyiron = np.zeros_like(img_rgb, dtype=np.float32)

# Apply RGB to CMY conversion across the entire image
for i in range(img_rgb.shape[0]):  # Loop over rows (height)
    for j in range(img_rgb.shape[1]):  # Loop over columns (width)
        r, g, b = img_rgb[i, j]
        c, m, y = rgb_to_cmy(r, g, b)
        cmyiron[i, j] = [c, m, y]

# Display the CMY image
plt.figure(figsize=(12, 4))

# Cyan channel
plt.subplot(131)
plt.imshow(cmyiron[:,:,0], cmap='Blues')  # Cyan channel (C = 1 - R)
plt.title('Cyan Channel')
plt.axis('off')

# Magenta channel
plt.subplot(132)
plt.imshow(cmyiron[:,:,1], cmap='Purples')  # Magenta channel (M = 1 - G)
plt.title('Magenta Channel')
plt.axis('off')

# Yellow channel
plt.subplot(133)
plt.imshow(cmyiron[:,:,2], cmap='YlOrBr')  # Yellow channel (Y = 1 - B)
plt.title('Yellow Channel')
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image

rgb_image = iron

# Convert from BGR (OpenCV default) to RGB
rgb_image = cv2.cvtColor(rgb_image, cv2.COLOR_BGR2RGB)

# Convert RGB to CMY (Cyan, Magenta, Yellow)
cmyk_image = 1 - rgb_image / 255.0  # Normalize to [0, 1] range and invert to get CMY

# Split the CMY channels
c, m, y = cv2.split(cmyk_image)

# Modify the channels as per your request
# 1. Set Cyan and Magenta channels to 0 (only Yellow remains)
cmyk_image_cy_mg_zero = cv2.merge([np.zeros_like(c), np.zeros_like(m), y])

# 2. Set Cyan and Yellow channels to 0 (only Magenta remains)
cmyk_image_cy_yl_zero = cv2.merge([np.zeros_like(c), m, np.zeros_like(y)])

# 3. Set Magenta and Yellow channels to 0 (only Cyan remains)
cmyk_image_mg_yl_zero = cv2.merge([c, np.zeros_like(m), np.zeros_like(y)])

# Convert the CMY images back to RGB for proper display
rgb_cy_mg_zero = 255 * (1 - np.dstack([cmyk_image_cy_mg_zero[:, :, 0], cmyk_image_cy_mg_zero[:, :, 1], cmyk_image_cy_mg_zero[:, :, 2]]))
rgb_cy_yl_zero = 255 * (1 - np.dstack([cmyk_image_cy_yl_zero[:, :, 0], cmyk_image_cy_yl_zero[:, :, 1], cmyk_image_cy_yl_zero[:, :, 2]]))
rgb_mg_yl_zero = 255 * (1 - np.dstack([cmyk_image_mg_yl_zero[:, :, 0], cmyk_image_mg_yl_zero[:, :, 1], cmyk_image_mg_yl_zero[:, :, 2]]))

# Plot the modified CMY images
plt.figure(figsize=(12, 4))

# Show the image with Cyan and Magenta set to 0 (Yellow Only)
plt.subplot(1, 3, 1)
plt.imshow(rgb_cy_mg_zero.astype(np.uint8))
plt.title("Yellow Only (Cyan and Magenta Set to 0)")
plt.axis('off')

# Show the image with Cyan and Yellow set to 0 (Magenta Only)
plt.subplot(1, 3, 2)
plt.imshow(rgb_cy_yl_zero.astype(np.uint8))
plt.title("Magenta Only (Cyan and Yellow Set to 0)")
plt.axis('off')

# Show the image with Magenta and Yellow set to 0 (Cyan Only)
plt.subplot(1, 3, 3)
plt.imshow(rgb_mg_yl_zero.astype(np.uint8))
plt.title("Cyan Only (Magenta and Yellow Set to 0)")
plt.axis('off')

# Show the plots
plt.tight_layout()
plt.show()

# %%
import cv2
import numpy as np

def rgb_to_yiq(image):
    # RGB to YIQ transformation matrix
    rgb2yiq_matrix = np.array([
        [0.299,  0.587,  0.114],
        [0.596, -0.274, -0.322],
        [0.211, -0.523,  0.312]
    ])

    # Convert the image from BGR (OpenCV default) to RGB
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Apply the transformation matrix
    yiq_image = cv2.transform(image_rgb, rgb2yiq_matrix)

    return yiq_image

# Load an image using OpenCV
image = iron

# Convert the image to YIQ
yiq_image = rgb_to_yiq(image)

# Split the channels
Y, I, Q = cv2.split(yiq_image)

# Show the Y channel
cv2.imshow("Y Channel", Y / 255)  # Normalize for display
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 31
#      29 # Show the Y channel
#      30 cv2.imshow("Y Channel", Y / 255)  # Normalize for display
# ---> 31 cv2.waitKey(0)
#      32 cv2.destroyAllWindows()
#
# KeyboardInterrupt:

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def bgr_to_yiq(image):
    # BGR to YIQ transformation matrix
    bgr2yiq_matrix = np.array([
        [0.114, 0.587, 0.299],   # Y component
        [-0.322, -0.274, 0.596], # I component
        [0.312, -0.523, 0.211]   # Q component
    ])

    # Apply the transformation matrix
    yiq_image = cv2.transform(image, bgr2yiq_matrix)
    
    return yiq_image

# Load the image using OpenCV (BGR format)
image_bgr = iron

# Convert the image to YIQ
yiq_image = bgr_to_yiq(image_bgr)

# Split the channels
Y, I, Q = cv2.split(yiq_image)

# Convert BGR to RGB for correct color display
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

# Display images using Matplotlib
plt.figure(figsize=(12, 6))

plt.subplot(2, 2, 1)
plt.imshow(image_rgb)
plt.title("Original Image (RGB)")
plt.axis("off")

plt.subplot(2, 2, 2)
plt.imshow(Y, cmap='gray')
plt.title("Y Channel (Luminance)")
plt.axis("off")

plt.subplot(2, 2, 3)
plt.imshow(I, cmap='gray')
plt.title("I Channel (In-phase)")
plt.axis("off")

plt.subplot(2, 2, 4)
plt.imshow(Q, cmap='gray')
plt.title("Q Channel (Quadrature)")
plt.axis("off")

plt.show()

# %%
RGB=cv2.cvtColor(iron,cv2.COLOR_BGR2RGB) 
r,g,b=RGB[:,:,0],RGB[:,:,1],RGB[:,:,2] 
c=1-r/225 
m=1-g/225 
y=1-b/225 
i=(np.dstack((c,m,y))*255).astype(np.uint8) 
hsv=cv2.cvtColor(iron,cv2.COLOR_BGR2HSV) 
r1=r/225 
g1=g/225 
b1=b/225 
y=0.299*r1 + 0.587*g1 + 0.114*b1  
ii=0.596*r1 - 0.274*g1 - 0.321*b1 
q=0.211*r1 - 0.522*g1 + 0.311*b1 
yiq=(np.dstack((y,ii,q))*255).astype(np.uint8) 
plt.figure(figsize=(14,6 )) 
plt.subplot(2,2,1) 
plt.imshow(iron) 
plt.title('ORIGINAL') 
plt.axis('off') 
plt.subplot(2,2,2) 
plt.imshow(i) 
plt.title('CMY') 
plt.axis('off') 
plt.subplot(2,2,3) 
plt.imshow(hsv) 
plt.title('HSV') 
plt.axis('off') 
plt.subplot(2,2,4) 
plt.title('YIQ') 
plt.imshow(yiq) 
plt.axis('off')
# Out:
# (-0.5, 299.5, 167.5, -0.5)
